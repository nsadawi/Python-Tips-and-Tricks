# %%
# !./pip install matplotlib_venn
# Out:
# Collecting matplotlib_venn
#   Downloading matplotlib-venn-0.11.4.zip (40kB)
#     100% |████████████████████████████████| 40kB 1.6MB/s
# Requirement already satisfied: matplotlib in /home/noureddin/anaconda3/lib/python3.5/site-packages (from matplotlib_venn)
# Requirement already satisfied: numpy in /home/noureddin/anaconda3/lib/python3.5/site-packages (from matplotlib_venn)
# Requirement already satisfied: scipy in /home/noureddin/anaconda3/lib/python3.5/site-packages (from matplotlib_venn)
# Requirement already satisfied: python-dateutil in /home/noureddin/anaconda3/lib/python3.5/site-packages (from matplotlib->matplotlib_venn)
# Requirement already satisfied: pytz in /home/noureddin/anaconda3/lib/python3.5/site-packages (from matplotlib->matplotlib_venn)
# Requirement already satisfied: cycler in /home/noureddin/anaconda3/lib/python3.5/site-packages (from matplotlib->matplotlib_venn)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,>=1.5.6 in /home/noureddin/anaconda3/lib/python3.5/site-packages (from matplotlib->matplotlib_venn)
# Requirement already satisfied: six>=1.5 in /home/noureddin/anaconda3/lib/python3.5/site-packages (from python-dateutil->matplotlib->matplotlib_venn)
# Building wheels for collected packages: matplotlib-venn
# done
#   Stored in directory: /home/noureddin/.cache/pip/wheels/13/d2/77/77e48b19e5e9e0184137e34bcedd2b95968054cd59ab9540d3
# Successfully built matplotlib-venn
# Installing collected packages: matplotlib-venn
# Successfully installed matplotlib-venn-0.11.4

# %%
# %matplotlib inline
import matplotlib_venn as vplt
from matplotlib import pyplot as plt

# %%
v = vplt.venn2(subsets={'10': 1, '01': 1, '11': 1}, set_labels = ('A', 'B'))
v.get_label_by_id('A').set_text('Set A')
plt.show()

# %%
dir(vplt)
# Out:
# ['___all___',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_arc',
#  '_common',
#  '_math',
#  '_region',
#  '_util',
#  '_venn2',
#  '_venn3',
#  'venn2',
#  'venn2_circles',
#  'venn2_unweighted',
#  'venn3',
#  'venn3_circles',
#  'venn3_unweighted']

# %%
v = vplt.venn3(subsets=(1, 2, 3, 4, 5, 6, 7), set_labels = ('A', 'B', 'C'))
